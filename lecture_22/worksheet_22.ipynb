# %% [markdown]
# # Worksheet 22
#
# Name:  Sumatra Dhimoyee
# UID: U26967910
#
# ### Topics
#
# - Neural Networks
#
# ## Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
import tensorflow as tf
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu
 
#       x[0] --- h1 
#            \ /    \
#             X       output
#            / \    /
#       x[1] --- h2
#
# This is the base model - nothing fancy here

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(n_samples=200, centers=centers, cluster_std=1,
                                random_state=1)

colors = np.array([x for x in 'bgrcmyk'])
colors = np.hstack([colors] * 20)

# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 < 1 or (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 > 1.5, t)))
    Y = np.array([1 if (x[0] - centers[0][0])**2 + (x[1] - centers[0][1])**2 >= 1 else 0 for x in X])
    return X, Y

# LINE
def generate_line_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : x[0] - x[1] < -.5 or x[0] - x[1] > .5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y

# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x : m.cos(4*x[0]) - x[1] < -.5 or m.cos(4*x[0]) - x[1] > .5, t)))
    Y = np.array([1 if m.cos(4*x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y

# XOR
def generate_xor_data():
    X = np.array([
        [0,0],
        [0,1],
        [1,0],
        [1,1]])
    Y = np.array([x[0]^x[1] for x in X])
    return X, Y

PLOT_HIDDEN_LAYER_2D = False
PLOT_HIDDEN_LAYER_3D = True

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(2, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

# X, Y = generate_circle_data(t)
# X, Y = generate_line_data(t)
# X, Y = generate_curve_data(t)
X, Y = generate_xor_data()

# plot the data
plt.scatter(X[:,0],X[:,1],color=colors[Y].tolist(), s=100, alpha=.9)
plt.show()

history = model.fit(X, Y, batch_size=1, epochs=1000)

if PLOT_HIDDEN_LAYER_2D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = tf.keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    plt.scatter(layerVals[:,0], layerVals[:, 1], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .02  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel()]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=2, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
    ax.set_xlabel("h0")
    ax.set_ylabel("h1")
    plt.show()

if PLOT_HIDDEN_LAYER_3D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = tf.keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(layerVals[:,0], layerVals[:, 1], layerVals[:, 2], color=colors[Y].tolist(), s=100, alpha=.9)
    plt.show()

    # create a mesh to plot in
    h = .1  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - .5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - .5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                        np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel(), np.zeros(len(xx.ravel()))]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=3, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < .5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired) # plot in 2D
    ax.axis('off')

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < .5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=.9) # plot in 2D
    plt.show()

# Plot the decision boundary

# create a mesh to plot in
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < .5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=.3, cmap=plt.cm.Paired)
ax.axis('off')

# Plot also the training points
T = model.predict(X)
T = np.array([0 if x < .5 else 1 for x in T])
T = T.reshape(X[:,0].shape)
ax.scatter(X[:, 0], X[:, 1], color=colors[T].tolist(), s=100, alpha=.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# /Users/sumatradhimoyee/Library/Python/3.9/lib/python/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7382
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.7374
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.7371
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.7368
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.7366
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.7364
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.7363
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - loss: 0.7361
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.7359
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.7358
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step - loss: 0.7356
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step - loss: 0.7354
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - loss: 0.7353
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.7351
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - loss: 0.7350
# Epoch 16/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.7348
# Epoch 17/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.7347
# Epoch 18/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.7345
# Epoch 19/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - loss: 0.7344
# Epoch 20/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.7342
# Epoch 21/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.7341
# Epoch 22/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.7339
# Epoch 23/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.7338
# Epoch 24/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.7336
# Epoch 25/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.7335
# Epoch 26/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.7333
# Epoch 27/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step - loss: 0.7332
# Epoch 28/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.7330
# Epoch 29/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.7329
# Epoch 30/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.7327
# Epoch 31/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.7326
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.7324
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.7323
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 0.7321
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - loss: 0.7320
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.7318
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.7317
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.7316
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.7314
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.7313
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.7311
# Epoch 42/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.7310
# Epoch 43/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.7308
# Epoch 44/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 0.7307
# Epoch 45/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.7306
# Epoch 46/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.7304
# Epoch 47/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.7303
# Epoch 48/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.7302
# Epoch 49/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.7300
# Epoch 50/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - loss: 0.7299
# Epoch 51/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.7297
# Epoch 52/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.7296
# Epoch 53/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step - loss: 0.7295
# Epoch 54/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.7293
# Epoch 55/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.7292
# Epoch 56/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.7291
# Epoch 57/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.7289
# Epoch 58/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step - loss: 0.7288
# Epoch 59/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.7287
# Epoch 60/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.7285
# Epoch 61/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.7284
# Epoch 62/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.7283
# Epoch 63/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.7281
# Epoch 64/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.7280
# Epoch 65/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step - loss: 0.7279
# Epoch 66/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.7277
# Epoch 67/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.7276
# Epoch 68/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.7275
# Epoch 69/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7273
# Epoch 70/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.7272
# Epoch 71/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.7271
# Epoch 72/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.7269
# Epoch 73/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.7268
# Epoch 74/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.7267
# Epoch 75/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.7266
# Epoch 76/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.7264
# Epoch 77/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.7263
# Epoch 78/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step - loss: 0.7262
# Epoch 79/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 0.7261
# Epoch 80/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.7259
# Epoch 81/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 0.7258
# Epoch 82/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 0.7257
# Epoch 83/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.7256
# Epoch 84/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - loss: 0.7254
# Epoch 85/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.7253
# Epoch 86/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.7252
# Epoch 87/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.7251
# Epoch 88/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.7249
# Epoch 89/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.7248
# Epoch 90/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7247
# Epoch 91/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.7246
# Epoch 92/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.7244
# Epoch 93/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.7243
# Epoch 94/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.7242
# Epoch 95/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.7241
# Epoch 96/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.7240
# Epoch 97/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - loss: 0.7238
# Epoch 98/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.7237
# Epoch 99/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.7236
# Epoch 100/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.7235
# Epoch 101/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7234
# Epoch 102/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.7232
# Epoch 103/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.7231
# Epoch 104/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.7230
# Epoch 105/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.7229
# Epoch 106/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.7228
# Epoch 107/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - loss: 0.7227
# Epoch 108/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.7225
# Epoch 109/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.7224
# Epoch 110/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 616us/step - loss: 0.7223
# Epoch 111/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.7222
# Epoch 112/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.7221
# Epoch 113/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.7220
# Epoch 114/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.7219
# Epoch 115/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.7217
# Epoch 116/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.7216
# Epoch 117/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.7215
# Epoch 118/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.7214
# Epoch 119/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.7213
# Epoch 120/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.7212
# Epoch 121/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.7211
# Epoch 122/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.7210
# Epoch 123/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.7208
# Epoch 124/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.7207
# Epoch 125/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.7206
# Epoch 126/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.7205
# Epoch 127/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.7204
# Epoch 128/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.7203
# Epoch 129/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.7202
# Epoch 130/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.7201
# Epoch 131/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.7200
# Epoch 132/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 0.7199
# Epoch 133/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.7197
# Epoch 134/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.7196
# Epoch 135/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.7195
# Epoch 136/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.7194
# Epoch 137/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.7193
# Epoch 138/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.7192
# Epoch 139/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.7191
# Epoch 140/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.7190
# Epoch 141/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.7189
# Epoch 142/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.7188
# Epoch 143/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.7187
# Epoch 144/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.7186
# Epoch 145/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - loss: 0.7185
# Epoch 146/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.7184
# Epoch 147/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7183
# Epoch 148/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.7182
# Epoch 149/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7180
# Epoch 150/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - loss: 0.7179
# Epoch 151/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.7178
# Epoch 152/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.7177
# Epoch 153/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step - loss: 0.7176
# Epoch 154/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.7175
# Epoch 155/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.7174
# Epoch 156/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.7173
# Epoch 157/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.7172
# Epoch 158/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.7171
# Epoch 159/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.7170
# Epoch 160/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.7169
# Epoch 161/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.7168
# Epoch 162/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.7167
# Epoch 163/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.7166
# Epoch 164/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.7165
# Epoch 165/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step - loss: 0.7164
# Epoch 166/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.7163
# Epoch 167/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.7162
# Epoch 168/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.7161
# Epoch 169/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.7160
# Epoch 170/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 0.7159
# Epoch 171/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.7158
# Epoch 172/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.7157
# Epoch 173/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.7156
# Epoch 174/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.7155
# Epoch 175/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.7154
# Epoch 176/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.7153
# Epoch 177/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.7152
# Epoch 178/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.7151
# Epoch 179/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.7150
# Epoch 180/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.7149
# Epoch 181/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.7148
# Epoch 182/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.7148
# Epoch 183/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.7147
# Epoch 184/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.7146
# Epoch 185/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.7145
# Epoch 186/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.7144
# Epoch 187/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.7143
# Epoch 188/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.7142
# Epoch 189/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.7141
# Epoch 190/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.7140
# Epoch 191/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.7139
# Epoch 192/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.7138
# Epoch 193/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.7137
# Epoch 194/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.7136
# Epoch 195/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.7135
# Epoch 196/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.7134
# Epoch 197/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.7133
# Epoch 198/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.7132
# Epoch 199/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.7131
# Epoch 200/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 0.7131
# Epoch 201/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.7130
# Epoch 202/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.7129
# Epoch 203/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.7128
# Epoch 204/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.7127
# Epoch 205/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7126
# Epoch 206/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.7125
# Epoch 207/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.7124
# Epoch 208/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.7123
# Epoch 209/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7122
# Epoch 210/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.7121
# Epoch 211/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.7121
# Epoch 212/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.7120
# Epoch 213/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.7119
# Epoch 214/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.7118
# Epoch 215/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.7117
# Epoch 216/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.7116
# Epoch 217/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.7115
# Epoch 218/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.7114
# Epoch 219/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.7113
# Epoch 220/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.7112
# Epoch 221/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.7112
# Epoch 222/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.7111
# Epoch 223/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.7110
# Epoch 224/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.7109
# Epoch 225/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.7108
# Epoch 226/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.7107
# Epoch 227/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.7106
# Epoch 228/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.7105
# Epoch 229/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.7105
# Epoch 230/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.7104
# Epoch 231/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.7103
# Epoch 232/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.7102
# Epoch 233/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.7101
# Epoch 234/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.7100
# Epoch 235/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.7099
# Epoch 236/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.7099
# Epoch 237/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.7098
# Epoch 238/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.7097
# Epoch 239/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7096
# Epoch 240/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.7095
# Epoch 241/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.7094
# Epoch 242/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.7093
# Epoch 243/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.7093
# Epoch 244/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.7092
# Epoch 245/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.7091
# Epoch 246/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.7090
# Epoch 247/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.7089
# Epoch 248/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.7088
# Epoch 249/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.7088
# Epoch 250/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.7087
# Epoch 251/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.7086
# Epoch 252/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.7085
# Epoch 253/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.7084
# Epoch 254/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.7083
# Epoch 255/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7082
# Epoch 256/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.7082
# Epoch 257/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.7081
# Epoch 258/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.7080
# Epoch 259/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.7079
# Epoch 260/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.7078
# Epoch 261/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.7078
# Epoch 262/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step - loss: 0.7077
# Epoch 263/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.7076
# Epoch 264/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7075
# Epoch 265/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.7074
# Epoch 266/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 0.7073
# Epoch 267/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.7073
# Epoch 268/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - loss: 0.7072
# Epoch 269/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.7071
# Epoch 270/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.7070
# Epoch 271/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.7069
# Epoch 272/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 0.7069
# Epoch 273/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.7068
# Epoch 274/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.7067
# Epoch 275/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.7066
# Epoch 276/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.7065
# Epoch 277/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.7065
# Epoch 278/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.7064
# Epoch 279/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.7063
# Epoch 280/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.7062
# Epoch 281/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.7061
# Epoch 282/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.7061
# Epoch 283/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.7060
# Epoch 284/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.7059
# Epoch 285/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7058
# Epoch 286/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.7057
# Epoch 287/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.7057
# Epoch 288/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.7056
# Epoch 289/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.7055
# Epoch 290/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.7054
# Epoch 291/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.7053
# Epoch 292/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.7053
# Epoch 293/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.7052
# Epoch 294/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.7051
# Epoch 295/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.7050
# Epoch 296/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.7050
# Epoch 297/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.7049
# Epoch 298/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.7048
# Epoch 299/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.7047
# Epoch 300/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.7046
# Epoch 301/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.7046
# Epoch 302/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.7045
# Epoch 303/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.7044
# Epoch 304/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.7043
# Epoch 305/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.7043
# Epoch 306/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - loss: 0.7042
# Epoch 307/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.7041
# Epoch 308/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.7040
# Epoch 309/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.7040
# Epoch 310/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.7039
# Epoch 311/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.7038
# Epoch 312/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.7037
# Epoch 313/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.7037
# Epoch 314/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.7036
# Epoch 315/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.7035
# Epoch 316/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.7034
# Epoch 317/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.7033
# Epoch 318/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 0.7033
# Epoch 319/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.7032
# Epoch 320/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.7031
# Epoch 321/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.7030
# Epoch 322/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.7030
# Epoch 323/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.7029
# Epoch 324/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.7028
# Epoch 325/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.7027
# Epoch 326/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7027
# Epoch 327/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.7026
# Epoch 328/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.7025
# Epoch 329/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.7024
# Epoch 330/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.7024
# Epoch 331/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.7023
# Epoch 332/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.7022
# Epoch 333/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.7021
# Epoch 334/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.7021
# Epoch 335/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.7020
# Epoch 336/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.7019
# Epoch 337/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.7019
# Epoch 338/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.7018
# Epoch 339/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.7017
# Epoch 340/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.7016
# Epoch 341/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.7016
# Epoch 342/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.7015
# Epoch 343/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.7014
# Epoch 344/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.7013
# Epoch 345/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.7013
# Epoch 346/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.7012
# Epoch 347/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.7011
# Epoch 348/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.7010
# Epoch 349/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.7010
# Epoch 350/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.7009
# Epoch 351/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.7008
# Epoch 352/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.7008
# Epoch 353/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.7007
# Epoch 354/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.7006
# Epoch 355/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.7005
# Epoch 356/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.7005
# Epoch 357/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.7004
# Epoch 358/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.7003
# Epoch 359/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.7002
# Epoch 360/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.7002
# Epoch 361/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.7001
# Epoch 362/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.7000
# Epoch 363/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.7000
# Epoch 364/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.6999
# Epoch 365/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6998
# Epoch 366/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6997
# Epoch 367/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6997
# Epoch 368/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.6996
# Epoch 369/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6995
# Epoch 370/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.6995
# Epoch 371/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6994
# Epoch 372/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.6993
# Epoch 373/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.6992
# Epoch 374/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6992
# Epoch 375/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6991
# Epoch 376/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6990
# Epoch 377/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6990
# Epoch 378/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.6989
# Epoch 379/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.6988
# Epoch 380/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.6987
# Epoch 381/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6987
# Epoch 382/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.6986
# Epoch 383/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.6985
# Epoch 384/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.6985
# Epoch 385/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6984
# Epoch 386/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 0.6983
# Epoch 387/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6983
# Epoch 388/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.6982
# Epoch 389/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.6981
# Epoch 390/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.6980
# Epoch 391/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6980
# Epoch 392/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - loss: 0.6979
# Epoch 393/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.6978
# Epoch 394/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.6978
# Epoch 395/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 0.6977
# Epoch 396/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.6976
# Epoch 397/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6975
# Epoch 398/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.6975
# Epoch 399/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.6974
# Epoch 400/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.6973
# Epoch 401/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.6973
# Epoch 402/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.6972
# Epoch 403/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.6971
# Epoch 404/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.6971
# Epoch 405/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.6970
# Epoch 406/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.6969
# Epoch 407/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.6969
# Epoch 408/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.6968
# Epoch 409/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.6967
# Epoch 410/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6966
# Epoch 411/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.6966
# Epoch 412/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.6965
# Epoch 413/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.6964
# Epoch 414/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.6964
# Epoch 415/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.6963
# Epoch 416/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.6962
# Epoch 417/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.6962
# Epoch 418/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.6961
# Epoch 419/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.6960
# Epoch 420/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.6960
# Epoch 421/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.6959
# Epoch 422/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6958
# Epoch 423/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.6957
# Epoch 424/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6957
# Epoch 425/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.6956
# Epoch 426/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6955
# Epoch 427/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.6955
# Epoch 428/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6954
# Epoch 429/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.6953
# Epoch 430/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6953
# Epoch 431/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.6952
# Epoch 432/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.6951
# Epoch 433/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6951
# Epoch 434/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6950
# Epoch 435/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.6949
# Epoch 436/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.6949
# Epoch 437/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.6948
# Epoch 438/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.6947
# Epoch 439/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.6946
# Epoch 440/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.6946
# Epoch 441/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.6945
# Epoch 442/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6944
# Epoch 443/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6944
# Epoch 444/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.6943
# Epoch 445/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.6942
# Epoch 446/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.6942
# Epoch 447/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6941
# Epoch 448/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6940
# Epoch 449/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.6940
# Epoch 450/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6939
# Epoch 451/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6938
# Epoch 452/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6938
# Epoch 453/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.6937
# Epoch 454/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.6936
# Epoch 455/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6936
# Epoch 456/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.6935
# Epoch 457/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.6934
# Epoch 458/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.6934
# Epoch 459/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.6933
# Epoch 460/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6932
# Epoch 461/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 0.6931
# Epoch 462/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6931
# Epoch 463/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.6930
# Epoch 464/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.6929
# Epoch 465/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.6929
# Epoch 466/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.6928
# Epoch 467/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.6927
# Epoch 468/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6927
# Epoch 469/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.6926
# Epoch 470/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6925
# Epoch 471/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6925
# Epoch 472/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.6924
# Epoch 473/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.6923
# Epoch 474/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.6923
# Epoch 475/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6922
# Epoch 476/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6921
# Epoch 477/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.6921
# Epoch 478/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.6920
# Epoch 479/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6919
# Epoch 480/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.6919
# Epoch 481/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.6918
# Epoch 482/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6917
# Epoch 483/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.6917
# Epoch 484/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.6916
# Epoch 485/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.6915
# Epoch 486/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6915
# Epoch 487/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6914
# Epoch 488/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.6913
# Epoch 489/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.6913
# Epoch 490/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6912
# Epoch 491/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.6911
# Epoch 492/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.6910
# Epoch 493/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 0.6910
# Epoch 494/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6909
# Epoch 495/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 0.6908
# Epoch 496/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.6908
# Epoch 497/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - loss: 0.6907
# Epoch 498/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.6906
# Epoch 499/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.6906
# Epoch 500/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.6905
# Epoch 501/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.6904
# Epoch 502/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.6904
# Epoch 503/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.6903
# Epoch 504/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.6902
# Epoch 505/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6902
# Epoch 506/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - loss: 0.6901
# Epoch 507/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.6900
# Epoch 508/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.6900
# Epoch 509/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.6899
# Epoch 510/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6898
# Epoch 511/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.6898
# Epoch 512/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.6897
# Epoch 513/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6896
# Epoch 514/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6896
# Epoch 515/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.6895
# Epoch 516/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6894
# Epoch 517/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6894
# Epoch 518/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.6893
# Epoch 519/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6892
# Epoch 520/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - loss: 0.6892
# Epoch 521/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 0.6891
# Epoch 522/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.6890
# Epoch 523/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.6890
# Epoch 524/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6889
# Epoch 525/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6888
# Epoch 526/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6888
# Epoch 527/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6887
# Epoch 528/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6886
# Epoch 529/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.6886
# Epoch 530/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.6885
# Epoch 531/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.6884
# Epoch 532/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6883
# Epoch 533/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.6883
# Epoch 534/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.6882
# Epoch 535/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.6881
# Epoch 536/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.6881
# Epoch 537/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6880
# Epoch 538/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.6879
# Epoch 539/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6879
# Epoch 540/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.6878
# Epoch 541/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.6877
# Epoch 542/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.6877
# Epoch 543/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.6876
# Epoch 544/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.6875
# Epoch 545/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.6875
# Epoch 546/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.6874
# Epoch 547/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6873
# Epoch 548/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.6873
# Epoch 549/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6872
# Epoch 550/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.6871
# Epoch 551/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6871
# Epoch 552/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.6870
# Epoch 553/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.6869
# Epoch 554/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6869
# Epoch 555/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.6868
# Epoch 556/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6867
# Epoch 557/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 440us/step - loss: 0.6867
# Epoch 558/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.6866
# Epoch 559/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.6865
# Epoch 560/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6865
# Epoch 561/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.6864
# Epoch 562/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6863
# Epoch 563/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.6862
# Epoch 564/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6862
# Epoch 565/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.6861
# Epoch 566/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6860
# Epoch 567/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6860
# Epoch 568/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6859
# Epoch 569/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.6858
# Epoch 570/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.6858
# Epoch 571/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.6857
# Epoch 572/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.6856
# Epoch 573/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6856
# Epoch 574/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.6855
# Epoch 575/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6854
# Epoch 576/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6854
# Epoch 577/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.6853
# Epoch 578/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.6852
# Epoch 579/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.6852
# Epoch 580/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.6851
# Epoch 581/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step - loss: 0.6850
# Epoch 582/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.6849
# Epoch 583/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - loss: 0.6849
# Epoch 584/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 0.6848
# Epoch 585/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.6847
# Epoch 586/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.6847
# Epoch 587/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6846
# Epoch 588/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6845
# Epoch 589/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.6845
# Epoch 590/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6844
# Epoch 591/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.6843
# Epoch 592/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.6843
# Epoch 593/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.6842
# Epoch 594/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6841
# Epoch 595/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.6841
# Epoch 596/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.6840
# Epoch 597/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.6839
# Epoch 598/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.6839
# Epoch 599/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6838
# Epoch 600/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6837
# Epoch 601/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6836
# Epoch 602/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.6836
# Epoch 603/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6835
# Epoch 604/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.6834
# Epoch 605/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.6834
# Epoch 606/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.6833
# Epoch 607/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6832
# Epoch 608/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 0.6832
# Epoch 609/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.6831
# Epoch 610/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.6830
# Epoch 611/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6830
# Epoch 612/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.6829
# Epoch 613/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6828
# Epoch 614/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.6827
# Epoch 615/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6827
# Epoch 616/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6826
# Epoch 617/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.6825
# Epoch 618/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6825
# Epoch 619/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.6824
# Epoch 620/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6823
# Epoch 621/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6823
# Epoch 622/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6822
# Epoch 623/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.6821
# Epoch 624/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.6820
# Epoch 625/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6820
# Epoch 626/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6819
# Epoch 627/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.6818
# Epoch 628/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6818
# Epoch 629/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.6817
# Epoch 630/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6816
# Epoch 631/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.6816
# Epoch 632/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.6815
# Epoch 633/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6814
# Epoch 634/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.6814
# Epoch 635/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6813
# Epoch 636/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.6812
# Epoch 637/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.6811
# Epoch 638/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6811
# Epoch 639/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6810
# Epoch 640/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.6809
# Epoch 641/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6809
# Epoch 642/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.6808
# Epoch 643/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 0.6807
# Epoch 644/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.6806
# Epoch 645/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.6806
# Epoch 646/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.6805
# Epoch 647/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6804
# Epoch 648/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.6804
# Epoch 649/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.6803
# Epoch 650/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6802
# Epoch 651/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6802
# Epoch 652/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6801
# Epoch 653/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.6800
# Epoch 654/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6799
# Epoch 655/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.6799
# Epoch 656/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.6798
# Epoch 657/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.6797
# Epoch 658/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.6797
# Epoch 659/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.6796
# Epoch 660/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.6795
# Epoch 661/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6794
# Epoch 662/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6794
# Epoch 663/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6793
# Epoch 664/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6792
# Epoch 665/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6792
# Epoch 666/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - loss: 0.6791
# Epoch 667/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.6790
# Epoch 668/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.6789
# Epoch 669/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.6789
# Epoch 670/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.6788
# Epoch 671/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.6787
# Epoch 672/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.6787
# Epoch 673/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6786
# Epoch 674/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.6785
# Epoch 675/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6784
# Epoch 676/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6784
# Epoch 677/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.6783
# Epoch 678/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.6782
# Epoch 679/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 0.6782
# Epoch 680/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.6781
# Epoch 681/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6780
# Epoch 682/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6779
# Epoch 683/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.6779
# Epoch 684/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6778
# Epoch 685/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.6777
# Epoch 686/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 0.6776
# Epoch 687/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6776
# Epoch 688/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.6775
# Epoch 689/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6774
# Epoch 690/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6774
# Epoch 691/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6773
# Epoch 692/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.6772
# ...
# Epoch 786/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6701
# Epoch 787/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6700
# Epoch 788/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.6699
# Epoch 789/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.6699
# Epoch 790/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.6698
# Epoch 791/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.6697
# Epoch 792/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6696
# Epoch 793/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.6695
# Epoch 794/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.6695
# Epoch 795/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 0.6694
# Epoch 796/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.6693
# Epoch 797/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - loss: 0.6692
# Epoch 798/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.6691
# Epoch 799/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.6691
# Epoch 800/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.6690
# Epoch 801/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6689
# Epoch 802/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 0.6688
# Epoch 803/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.6687
# Epoch 804/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.6687
# Epoch 805/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6686
# Epoch 806/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.6685
# Epoch 807/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6684
# Epoch 808/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 0.6683
# Epoch 809/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.6683
# Epoch 810/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.6682
# Epoch 811/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.6681
# Epoch 812/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.6680
# Epoch 813/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 0.6679
# Epoch 814/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.6679
# Epoch 815/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.6678
# Epoch 816/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.6677
# Epoch 817/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 0.6676
# Epoch 818/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.6675
# Epoch 819/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.6675
# Epoch 820/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.6674
# Epoch 821/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 0.6673
# Epoch 822/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.6672
# Epoch 823/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.6671
# Epoch 824/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 0.6671
# Epoch 825/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.6670
# Epoch 826/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - loss: 0.6669
# Epoch 827/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step - loss: 0.6668
# Epoch 828/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.6667
# Epoch 829/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - loss: 0.6666
# Epoch 830/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 0.6666
# Epoch 831/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.6665
# Epoch 832/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 556us/step - loss: 0.6664
# Epoch 833/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.6663
# Epoch 834/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.6662
# Epoch 835/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step - loss: 0.6662
# Epoch 836/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6661
# Epoch 837/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.6660
# Epoch 838/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6659
# Epoch 839/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6658
# Epoch 840/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.6657
# Epoch 841/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6657
# Epoch 842/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.6656
# Epoch 843/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step - loss: 0.6655
# Epoch 844/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.6654
# Epoch 845/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.6653
# Epoch 846/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.6652
# Epoch 847/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.6652
# Epoch 848/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.6651
# Epoch 849/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.6650
# Epoch 850/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6649
# Epoch 851/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6648
# Epoch 852/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6647
# Epoch 853/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.6647
# Epoch 854/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.6646
# Epoch 855/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.6645
# Epoch 856/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.6644
# Epoch 857/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.6643
# Epoch 858/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.6642
# Epoch 859/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.6641
# Epoch 860/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6641
# Epoch 861/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.6640
# Epoch 862/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6639
# Epoch 863/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.6638
# Epoch 864/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.6637
# Epoch 865/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 0.6636
# Epoch 866/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.6636
# Epoch 867/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.6635
# Epoch 868/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.6634
# Epoch 869/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.6633
# Epoch 870/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.6632
# Epoch 871/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step - loss: 0.6631
# Epoch 872/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.6630
# Epoch 873/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6630
# Epoch 874/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.6629
# Epoch 875/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.6628
# Epoch 876/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.6627
# Epoch 877/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6626
# Epoch 878/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.6625
# Epoch 879/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.6624
# Epoch 880/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.6624
# Epoch 881/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6623
# Epoch 882/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.6622
# Epoch 883/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6621
# Epoch 884/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.6620
# Epoch 885/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.6619
# Epoch 886/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6618
# Epoch 887/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.6618
# Epoch 888/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6617
# Epoch 889/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.6616
# Epoch 890/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.6615
# Epoch 891/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.6614
# Epoch 892/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.6613
# Epoch 893/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.6612
# Epoch 894/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6611
# Epoch 895/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.6611
# Epoch 896/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.6610
# Epoch 897/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.6609
# Epoch 898/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.6608
# Epoch 899/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 0.6607
# Epoch 900/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.6606
# Epoch 901/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.6605
# Epoch 902/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.6604
# Epoch 903/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.6603
# Epoch 904/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6603
# Epoch 905/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6602
# Epoch 906/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.6601
# Epoch 907/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.6600
# Epoch 908/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.6599
# Epoch 909/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.6598
# Epoch 910/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6597
# Epoch 911/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.6596
# Epoch 912/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.6596
# Epoch 913/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.6595
# Epoch 914/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 0.6594
# Epoch 915/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.6593
# Epoch 916/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.6592
# Epoch 917/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.6591
# Epoch 918/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6590
# Epoch 919/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step - loss: 0.6589
# Epoch 920/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.6588
# Epoch 921/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.6587
# Epoch 922/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.6587
# Epoch 923/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.6586
# Epoch 924/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6585
# Epoch 925/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.6584
# Epoch 926/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.6583
# Epoch 927/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6582
# Epoch 928/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.6581
# Epoch 929/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 553us/step - loss: 0.6580
# Epoch 930/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.6579
# Epoch 931/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.6578
# Epoch 932/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.6578
# Epoch 933/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 542us/step - loss: 0.6577
# Epoch 934/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.6576
# Epoch 935/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.6575
# Epoch 936/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.6574
# Epoch 937/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.6573
# Epoch 938/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6572
# Epoch 939/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.6571
# Epoch 940/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6570
# Epoch 941/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.6569
# Epoch 942/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6568
# Epoch 943/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.6567
# Epoch 944/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.6567
# Epoch 945/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.6566
# Epoch 946/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.6565
# Epoch 947/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step - loss: 0.6564
# Epoch 948/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.6563
# Epoch 949/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.6562
# Epoch 950/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.6561
# Epoch 951/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.6560
# Epoch 952/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 0.6559
# Epoch 953/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 0.6558
# Epoch 954/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.6557
# Epoch 955/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 582us/step - loss: 0.6556
# Epoch 956/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 0.6555
# Epoch 957/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.6555
# Epoch 958/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 0.6554
# Epoch 959/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.6553
# Epoch 960/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.6552
# Epoch 961/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.6551
# Epoch 962/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.6550
# Epoch 963/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.6549
# Epoch 964/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.6548
# Epoch 965/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.6547
# Epoch 966/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6546
# Epoch 967/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.6545
# Epoch 968/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - loss: 0.6544
# Epoch 969/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.6543
# Epoch 970/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.6542
# Epoch 971/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 482us/step - loss: 0.6541
# Epoch 972/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.6540
# Epoch 973/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.6539
# Epoch 974/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.6539
# Epoch 975/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.6538
# Epoch 976/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.6537
# Epoch 977/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.6536
# Epoch 978/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.6535
# Epoch 979/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6534
# Epoch 980/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.6533
# Epoch 981/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.6532
# Epoch 982/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.6531
# Epoch 983/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.6530
# Epoch 984/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 0.6529
# Epoch 985/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.6528
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.6527
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 521us/step - loss: 0.6526
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.6525
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.6524
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.6523
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.6522
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 486us/step - loss: 0.6521
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.6520
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.6519
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.6518
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 0.6517
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.6516
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.6515
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.6514
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.6514
# {'name': 'dense_4', 'trainable': True, 'dtype': 'float32', 'units': 2, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None} [array([[-2.050763  , -0.7658576 ],
#        [-1.8047907 , -0.24592152]], dtype=float32), array([ 0.02429262, -0.01711427], dtype=float32)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 125
#     123 layer = model.layers[0]
#     124 print(layer.get_config(), layer.get_weights())
# --> 125 keras_function = tf.keras.backend.function([model.input], [layer.output])
#     126 layerVals = np.array(keras_function(X))[0]
#     127 fig = plt.figure()
#
# AttributeError: module 'keras._tf_keras.keras.backend' has no attribute 'function'
