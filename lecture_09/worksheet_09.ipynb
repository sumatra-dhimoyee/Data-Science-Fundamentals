# %% [markdown]
# # Worksheet 09
#
# Name:  Patrick Meade
#
# UID:   31683289
#
# ### Topics
#
# - Clustering Review
# - Clustering Aggregation

# %% [markdown]
# ### Clustering Aggregation
#
# | Point | C | P |
# |-------|---|---|
# | A     | 0 | a |
# | B     | 0 | b |
# | C     | 2 | b |
# | D     | 1 | c |
# | E     | 1 | d |
#
# a) Fill in the following table where for each pair of points determine whether C and P agree or disagree on how to cluster that pair.

# %% [markdown]
# | Pair | Disagreement |
# |------|--------------|
# | A  B |      Yes       |
# | A  C |      Yes       |
# | A  D |      Yes       |
# | A  E |      Yes       |
# | B  C |      No       |
# | B  D |      Yes      |
# | B  E |      Yes       |
# | C  D |      Yes       |
# | C  E |      Yes     |
# | D  E |      No       |

# %% [markdown]
# As datasets become very large, this process can become computationally challenging.
#
# b) Given N points, what is the formula for the number of unique pairs of points one can create?

# %% [markdown]
# (N(N-1))/2

# %% [markdown]
# Assume that clustering C clusters all points in the same cluster and clustering P clusters points as such:
#
# | Point | P |
# |-------|---|
# | A     | 0 |
# | B     | 0 |
# | C     | 0 |
# | D     | 1 |
# | E     | 1 |
# | F     | 2 |
# | G     | 2 |
# | H     | 2 |
# | I     | 2 |
#
# c) What is the maximum number of disagreements there could be for a dataset of this size? (use the formula from b)?

# %% [markdown]
# (9(9-1))/2  = 36

# %% [markdown]
# d) If we look at cluster 0. There are (3 x 2) / 2 = 3 pairs that agree with C (since all points in C are in the same cluster). For each cluster, determine how many agreements there are. How many total agreements are there? How many disagreements does that mean there are between C and P?

# %% [markdown]
# For cluster 0: 3
# For cluster 1: 0
# For cluster 2: 3 + 0 + 6 = 9
#
# Total disagreements: 36 - 9 = 27

# %% [markdown]
# e) Assuming that filtering the dataset by cluster number is a computationally easy operation, describe an algorithm inspired by the above process that can efficiently compute disagreement distances on large datasets.

# %% [markdown]
# An algorithm inspired by the above process would efficiently computes disagreement distances on large datasets by categorizing points into clusters for both clustering C and clustering P. It calculates the agreements and disagreements based on these clusters and then sums the disagreements to obtain the total disagreement count.
