# %% [markdown]
# # Worksheet 02
#
# Name:
# UID:
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# not able to debug from get-go

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# you cannot plan everything beforehand

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# 1. read the error
# 2. re-read the code
# 3. check if the environment is setup properly

# %% [markdown]
# d) (Optional) Follow along with the live coding. You can write your code here:

# %%
class Board:
    ## add N later for N queens
    def __init__(self):
        self.board = [["-" for _ in range(8)] for _ in range(8)]

    def __repr__(self):
        res = ""
        for row in range(len(self.board)):
            for col in range(len(self.board)):
                res += self.board[row][col]
                res += " "
            res+="\n"
        return res

    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"

    def unset_queen_at_row(self, row):
        self.board[row] = ["-" for _ in range(8)]

    def find_solution(self):
        
        

test = Board()
test.set_queen_at(1, 1)
print(test)
# Out:
# - - - - - - - -
# - Q - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -
# - - - - - - - -

# %% [markdown]
# ## Exercise
#
# This exercise will use the [Titanic dataset](https://www.kaggle.com/c/titanic/data) (https://www.kaggle.com/c/titanic/data). Download the file named `train.csv` and place it in the same folder as this notebook.
#
# The goal of this exercise is to practice using [pandas](https://pypi.org/project/pandas/) methods. If your:
#
# 1. code is taking a long time to run
# 2. code involves for loops or while loops
# 3. code spans multiple lines
#
# look through the pandas documentation for alternatives. This [cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) may come in handy.
#
# a) Complete the code below to read in a filepath to the `train.csv` and returns the DataFrame.

# %%
import pandas as pd

df = pd.read_csv("./titanic/train.csv")# your code here
df.describe()
# df.head(10)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# b) Complete the code so it returns the number of rows that have at least one empty column value

# %%
empty_rows_count = len(df[df.isnull().any(axis=1)])
print("there are " +  str(empty_rows_count) + " rows with at least one empty value")
df.head(10)
# Out:
# there are 708 rows with at least one empty value
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# c) Complete the code below to remove all columns with more than 200 NaN values

# %%
df = df.dropna(axis=1, thresh=len(df) - 200)
df.columns
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S
# 5      0            330877   8.4583        Q
# 6      0             17463  51.8625        S
# 7      1            349909  21.0750        S
# 8      2            347742  11.1333        S
# 9      0            237736  30.0708        C

# %% [markdown]
# d) Complete the code below to replaces `male` with 0 and `female` with 1

# %%
df['Sex'] = df['Sex'].replace({'male': 0, 'female': 1})
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0   NaN      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    0   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S
# 5            330877   8.4583        Q
# 6             17463  51.8625        S
# 7            349909  21.0750        S
# 8            347742  11.1333        S
# 9            237736  30.0708        C

# %% [markdown]
# e) Complete the code below to add four columns `First Name`, `Middle Name`, `Last Name`, and `Title` corresponding to the value in the `name` column.
#
# For example: `Braund, Mr. Owen Harris` would be:
#
# |First Name | Middle Name | Last Name | Title |
# |-----------|-------------|-----------|-------|
# | Owen      |  Harris     |  Braund   | Mr    |
#
# Anything not clearly one of the above 4 categories can be ignored.

# %%
extracted_info = df['Name'].str.split(expand=True)
df[['First Name', 'Middle Name', 'Last Name', 'Title']] = extracted_info[[2, 3, 0, 1]]
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0   NaN      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    0   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1      0
#
#              Ticket     Fare Embarked First Name Middle Name   Last Name  \
# 0         A/5 21171   7.2500        S       Owen      Harris     Braund,
# 1          PC 17599  71.2833        C       John     Bradley    Cumings,
# 2  STON/O2. 3101282   7.9250        S      Laina        None  Heikkinen,
# 3            113803  53.1000        S    Jacques       Heath   Futrelle,
# 4            373450   8.0500        S    William       Henry      Allen,
# 5            330877   8.4583        Q      James        None      Moran,
# 6             17463  51.8625        S    Timothy           J   McCarthy,
# 7            349909  21.0750        S      Gosta     Leonard    Palsson,
# 8            347742  11.1333        S      Oscar           W    Johnson,
# 9            237736  30.0708        C   Nicholas      (Adele     Nasser,
#
#      Title
# 0      Mr.
# 1     Mrs.
# 2    Miss.
# 3     Mrs.
# 4      Mr.
# 5      Mr.
# 6      Mr.
# 7  Master.
# 8     Mrs.
# 9     Mrs.

# %% [markdown]
# f) Complete the code below to replace all missing ages with the average age

# %%
avg_age = df['Age'].mean(skipna=True)
df['Age'].fillna(avg_age, inplace=True)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex        Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    0  22.000000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                             Heikkinen, Miss. Laina    1  26.000000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                           Allen, Mr. William Henry    0  35.000000      0
# 5                                   Moran, Mr. James    0  29.699118      0
# 6                            McCarthy, Mr. Timothy J    0  54.000000      0
# 7                     Palsson, Master. Gosta Leonard    0   2.000000      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.000000      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.000000      1
#
#    Parch            Ticket     Fare Embarked First Name Middle Name  \
# 0      0         A/5 21171   7.2500        S       Owen      Harris
# 1      0          PC 17599  71.2833        C       John     Bradley
# 2      0  STON/O2. 3101282   7.9250        S      Laina        None
# 3      0            113803  53.1000        S    Jacques       Heath
# 4      0            373450   8.0500        S    William       Henry
# 5      0            330877   8.4583        Q      James        None
# 6      0             17463  51.8625        S    Timothy           J
# 7      1            349909  21.0750        S      Gosta     Leonard
# 8      2            347742  11.1333        S      Oscar           W
# 9      0            237736  30.0708        C   Nicholas      (Adele
#
#     Last Name    Title
# 0     Braund,      Mr.
# 1    Cumings,     Mrs.
# 2  Heikkinen,    Miss.
# 3   Futrelle,     Mrs.
# 4      Allen,      Mr.
# 5      Moran,      Mr.
# 6   McCarthy,      Mr.
# 7    Palsson,  Master.
# 8    Johnson,     Mrs.
# 9     Nasser,     Mrs.

# %% [markdown]
# g) Plot a bar chart of the average age of those that survived and did not survive. Briefly comment on what you observe.

# %%
# df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
# ax = df.plot.bar(x='lab', y='val', rot=0)

avg_age_survived = df[df['Survived'] == 1]['Age'].mean()
print (avg_age_survived)
avg_age_dead = df[df['Survived'] == 0]['Age'].mean()
print (avg_age_dead)

average_age_df = pd.DataFrame({
    'Survival Status': ['Survived', 'Dead'],
    'Average Age': [avg_age_survived, avg_age_dead]
})
average_age_df.plot.bar(x='Survival Status', y='Average Age', color=['blue', 'green'], rot=0)
# Out:
# 28.549778121775027
# 30.415099646415943
# <Axes: xlabel='Survival Status'>
